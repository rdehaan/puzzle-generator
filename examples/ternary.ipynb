# %%
import os
os.chdir('..')

from puzzle_generator import *

# %%
width = 9
height = 9
puzzle = RectangularPuzzle(
    width=width,
    height=height
)

puzzle.solving_timeout = 180

puzzle.naming = {
    None: '_',
    '0': '0',
    '1': '1',
    '2': '2',
}

puzzle.latex_naming = {
    None: ' ',
    '0': '\\Large \\ensuremath{0}',
    '1': '\\Large \\ensuremath{1}',
    '2': '\\Large \\ensuremath{2}',
}

puzzle.domain_program += f"""
    value(0;1;2).
"""

puzzle.puzzle_gen_program += """
    { puzzle(C,V) : cell(C), value(V) }.
"""
puzzle.puzzle_constraints_program += """
    #minimize { 1,puzzle(C,V) : puzzle(C,V) }.
"""

puzzle.solution_program = """
    1 { solution(C,V) : value(V) } 1 :- cell(C).
    solution(C,V) :- puzzle(C,V).
"""
puzzle.solution_program += enc_library['three_in_a_row']
puzzle.solution_program += """
    :- three_in_a_row(C1,C2,C3),
        value(V), solution(C1,V), solution(C2,V), solution(C3,V).
    
    :- value(V), row(Row), not board_width/3 { solution(c(Row,Col),V) : col(Col) } board_width/3.
    :- value(V), col(Col), not board_height/3 { solution(c(Row,Col),V) : row(Row) } board_height/3.
"""

puzzle.designated_solution_constraints = [
    """
    rows_diff(Row1,Row2) :- row(Row1), row(Row2), Row1 < Row2,
        col(Col), solution(c(Row1,Col),V1), solution(c(Row2,Col),V2),
        V1 != V2.
    :- row(Row1), row(Row2), Row1 < Row2, not rows_diff(Row1,Row2).

    cols_diff(Col1,Col2) :- col(Col1), col(Col2), Col1 < Col2,
        row(Row), solution(c(Row,Col1),V1), solution(c(Row,Col2),V2),
        V1 != V2.
    :- col(Col1), col(Col2), Col1 < Col2, not cols_diff(Col1,Col2).
    """,
#     """
    
#     """,
]

# %%
puzzle.generate(
    verbose=True,
    precompute_solution=False,
)
# Out:
# Done grounding..
# ...........................................
# Stopped after solving timeout..
# Solving time: 181.35 seconds

# %%
print(puzzle.pretty_repr_puzzle())
# Out:
# |0|1|1|0|_|_|0|1|_|
# |_|1|_|1|0|_|0|1|0|
# |_|0|_|_|2|_|1|0|0|
# |_|0|_|_|2|_|1|0|_|
# |_|_|_|_|_|_|_|_|_|
# |_|_|_|_|_|_|_|_|_|
# |2|0|2|2|_|_|_|_|0|
# |_|1|_|0|1|2|0|0|2|
# |_|_|_|_|0|1|_|_|_|

# %%
print(puzzle.pretty_repr_solution())
# Out:
# |0|1|1|0|2|2|0|1|2|
# |2|1|2|1|0|2|0|1|0|
# |2|0|1|2|2|1|1|0|0|
# |1|0|1|2|2|0|1|0|2|
# |0|2|0|0|1|1|2|2|1|
# |1|2|0|1|0|0|2|2|1|
# |2|0|2|2|1|0|1|1|0|
# |1|1|2|0|1|2|0|0|2|
# |0|2|0|1|0|1|2|2|1|

# %%
print(puzzle.latex_repr_puzzle())
# Out:
# \begin{tikzpicture}[scale=1]
#   \begin{scope}
#     \draw (0,0) grid (9,9);
#     \draw[ultra thick]
#       (0,0) rectangle (9,9);
#       \node[anchor=center] (1;1) at (0.5,8.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (1;2) at (1.5,8.5) {\Large \ensuremath{1}};
#       \node[anchor=center] (1;3) at (2.5,8.5) {\Large \ensuremath{1}};
#       \node[anchor=center] (1;4) at (3.5,8.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (1;5) at (4.5,8.5) { };
#       \node[anchor=center] (1;6) at (5.5,8.5) { };
#       \node[anchor=center] (1;7) at (6.5,8.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (1;8) at (7.5,8.5) {\Large \ensuremath{1}};
#       \node[anchor=center] (1;9) at (8.5,8.5) { };
#       \node[anchor=center] (2;1) at (0.5,7.5) { };
#       \node[anchor=center] (2;2) at (1.5,7.5) {\Large \ensuremath{1}};
#       \node[anchor=center] (2;3) at (2.5,7.5) { };
#       \node[anchor=center] (2;4) at (3.5,7.5) {\Large \ensuremath{1}};
#       \node[anchor=center] (2;5) at (4.5,7.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (2;6) at (5.5,7.5) { };
#       \node[anchor=center] (2;7) at (6.5,7.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (2;8) at (7.5,7.5) {\Large \ensuremath{1}};
#       \node[anchor=center] (2;9) at (8.5,7.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (3;1) at (0.5,6.5) { };
#       \node[anchor=center] (3;2) at (1.5,6.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (3;3) at (2.5,6.5) { };
#       \node[anchor=center] (3;4) at (3.5,6.5) { };
#       \node[anchor=center] (3;5) at (4.5,6.5) {\Large \ensuremath{2}};
#       \node[anchor=center] (3;6) at (5.5,6.5) { };
#       \node[anchor=center] (3;7) at (6.5,6.5) {\Large \ensuremath{1}};
#       \node[anchor=center] (3;8) at (7.5,6.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (3;9) at (8.5,6.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (4;1) at (0.5,5.5) { };
#       \node[anchor=center] (4;2) at (1.5,5.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (4;3) at (2.5,5.5) { };
#       \node[anchor=center] (4;4) at (3.5,5.5) { };
#       \node[anchor=center] (4;5) at (4.5,5.5) {\Large \ensuremath{2}};
#       \node[anchor=center] (4;6) at (5.5,5.5) { };
#       \node[anchor=center] (4;7) at (6.5,5.5) {\Large \ensuremath{1}};
#       \node[anchor=center] (4;8) at (7.5,5.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (4;9) at (8.5,5.5) { };
#       \node[anchor=center] (5;1) at (0.5,4.5) { };
#       \node[anchor=center] (5;2) at (1.5,4.5) { };
#       \node[anchor=center] (5;3) at (2.5,4.5) { };
#       \node[anchor=center] (5;4) at (3.5,4.5) { };
#       \node[anchor=center] (5;5) at (4.5,4.5) { };
#       \node[anchor=center] (5;6) at (5.5,4.5) { };
#       \node[anchor=center] (5;7) at (6.5,4.5) { };
#       \node[anchor=center] (5;8) at (7.5,4.5) { };
#       \node[anchor=center] (5;9) at (8.5,4.5) { };
#       \node[anchor=center] (6;1) at (0.5,3.5) { };
#       \node[anchor=center] (6;2) at (1.5,3.5) { };
#       \node[anchor=center] (6;3) at (2.5,3.5) { };
#       \node[anchor=center] (6;4) at (3.5,3.5) { };
#       \node[anchor=center] (6;5) at (4.5,3.5) { };
#       \node[anchor=center] (6;6) at (5.5,3.5) { };
#       \node[anchor=center] (6;7) at (6.5,3.5) { };
#       \node[anchor=center] (6;8) at (7.5,3.5) { };
#       \node[anchor=center] (6;9) at (8.5,3.5) { };
#       \node[anchor=center] (7;1) at (0.5,2.5) {\Large \ensuremath{2}};
#       \node[anchor=center] (7;2) at (1.5,2.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (7;3) at (2.5,2.5) {\Large \ensuremath{2}};
#       \node[anchor=center] (7;4) at (3.5,2.5) {\Large \ensuremath{2}};
#       \node[anchor=center] (7;5) at (4.5,2.5) { };
#       \node[anchor=center] (7;6) at (5.5,2.5) { };
#       \node[anchor=center] (7;7) at (6.5,2.5) { };
#       \node[anchor=center] (7;8) at (7.5,2.5) { };
#       \node[anchor=center] (7;9) at (8.5,2.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (8;1) at (0.5,1.5) { };
#       \node[anchor=center] (8;2) at (1.5,1.5) {\Large \ensuremath{1}};
#       \node[anchor=center] (8;3) at (2.5,1.5) { };
#       \node[anchor=center] (8;4) at (3.5,1.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (8;5) at (4.5,1.5) {\Large \ensuremath{1}};
#       \node[anchor=center] (8;6) at (5.5,1.5) {\Large \ensuremath{2}};
#       \node[anchor=center] (8;7) at (6.5,1.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (8;8) at (7.5,1.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (8;9) at (8.5,1.5) {\Large \ensuremath{2}};
#       \node[anchor=center] (9;1) at (0.5,0.5) { };
#       \node[anchor=center] (9;2) at (1.5,0.5) { };
#       \node[anchor=center] (9;3) at (2.5,0.5) { };
#       \node[anchor=center] (9;4) at (3.5,0.5) { };
#       \node[anchor=center] (9;5) at (4.5,0.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (9;6) at (5.5,0.5) {\Large \ensuremath{1}};
#       \node[anchor=center] (9;7) at (6.5,0.5) { };
#       \node[anchor=center] (9;8) at (7.5,0.5) { };
#       \node[anchor=center] (9;9) at (8.5,0.5) { };
#   \end{scope}
# \end{tikzpicture}

# %%
print(puzzle.latex_repr_solution())
# Out:
# \begin{tikzpicture}[scale=1]
#   \begin{scope}
#     \draw (0,0) grid (9,9);
#     \draw[ultra thick]
#       (0,0) rectangle (9,9);
#       \node[anchor=center] (1;1) at (0.5,8.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (1;2) at (1.5,8.5) {\Large \ensuremath{1}};
#       \node[anchor=center] (1;3) at (2.5,8.5) {\Large \ensuremath{1}};
#       \node[anchor=center] (1;4) at (3.5,8.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (1;5) at (4.5,8.5) {\Large \ensuremath{2}};
#       \node[anchor=center] (1;6) at (5.5,8.5) {\Large \ensuremath{2}};
#       \node[anchor=center] (1;7) at (6.5,8.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (1;8) at (7.5,8.5) {\Large \ensuremath{1}};
#       \node[anchor=center] (1;9) at (8.5,8.5) {\Large \ensuremath{2}};
#       \node[anchor=center] (2;1) at (0.5,7.5) {\Large \ensuremath{2}};
#       \node[anchor=center] (2;2) at (1.5,7.5) {\Large \ensuremath{1}};
#       \node[anchor=center] (2;3) at (2.5,7.5) {\Large \ensuremath{2}};
#       \node[anchor=center] (2;4) at (3.5,7.5) {\Large \ensuremath{1}};
#       \node[anchor=center] (2;5) at (4.5,7.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (2;6) at (5.5,7.5) {\Large \ensuremath{2}};
#       \node[anchor=center] (2;7) at (6.5,7.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (2;8) at (7.5,7.5) {\Large \ensuremath{1}};
#       \node[anchor=center] (2;9) at (8.5,7.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (3;1) at (0.5,6.5) {\Large \ensuremath{2}};
#       \node[anchor=center] (3;2) at (1.5,6.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (3;3) at (2.5,6.5) {\Large \ensuremath{1}};
#       \node[anchor=center] (3;4) at (3.5,6.5) {\Large \ensuremath{2}};
#       \node[anchor=center] (3;5) at (4.5,6.5) {\Large \ensuremath{2}};
#       \node[anchor=center] (3;6) at (5.5,6.5) {\Large \ensuremath{1}};
#       \node[anchor=center] (3;7) at (6.5,6.5) {\Large \ensuremath{1}};
#       \node[anchor=center] (3;8) at (7.5,6.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (3;9) at (8.5,6.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (4;1) at (0.5,5.5) {\Large \ensuremath{1}};
#       \node[anchor=center] (4;2) at (1.5,5.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (4;3) at (2.5,5.5) {\Large \ensuremath{1}};
#       \node[anchor=center] (4;4) at (3.5,5.5) {\Large \ensuremath{2}};
#       \node[anchor=center] (4;5) at (4.5,5.5) {\Large \ensuremath{2}};
#       \node[anchor=center] (4;6) at (5.5,5.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (4;7) at (6.5,5.5) {\Large \ensuremath{1}};
#       \node[anchor=center] (4;8) at (7.5,5.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (4;9) at (8.5,5.5) {\Large \ensuremath{2}};
#       \node[anchor=center] (5;1) at (0.5,4.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (5;2) at (1.5,4.5) {\Large \ensuremath{2}};
#       \node[anchor=center] (5;3) at (2.5,4.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (5;4) at (3.5,4.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (5;5) at (4.5,4.5) {\Large \ensuremath{1}};
#       \node[anchor=center] (5;6) at (5.5,4.5) {\Large \ensuremath{1}};
#       \node[anchor=center] (5;7) at (6.5,4.5) {\Large \ensuremath{2}};
#       \node[anchor=center] (5;8) at (7.5,4.5) {\Large \ensuremath{2}};
#       \node[anchor=center] (5;9) at (8.5,4.5) {\Large \ensuremath{1}};
#       \node[anchor=center] (6;1) at (0.5,3.5) {\Large \ensuremath{1}};
#       \node[anchor=center] (6;2) at (1.5,3.5) {\Large \ensuremath{2}};
#       \node[anchor=center] (6;3) at (2.5,3.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (6;4) at (3.5,3.5) {\Large \ensuremath{1}};
#       \node[anchor=center] (6;5) at (4.5,3.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (6;6) at (5.5,3.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (6;7) at (6.5,3.5) {\Large \ensuremath{2}};
#       \node[anchor=center] (6;8) at (7.5,3.5) {\Large \ensuremath{2}};
#       \node[anchor=center] (6;9) at (8.5,3.5) {\Large \ensuremath{1}};
#       \node[anchor=center] (7;1) at (0.5,2.5) {\Large \ensuremath{2}};
#       \node[anchor=center] (7;2) at (1.5,2.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (7;3) at (2.5,2.5) {\Large \ensuremath{2}};
#       \node[anchor=center] (7;4) at (3.5,2.5) {\Large \ensuremath{2}};
#       \node[anchor=center] (7;5) at (4.5,2.5) {\Large \ensuremath{1}};
#       \node[anchor=center] (7;6) at (5.5,2.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (7;7) at (6.5,2.5) {\Large \ensuremath{1}};
#       \node[anchor=center] (7;8) at (7.5,2.5) {\Large \ensuremath{1}};
#       \node[anchor=center] (7;9) at (8.5,2.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (8;1) at (0.5,1.5) {\Large \ensuremath{1}};
#       \node[anchor=center] (8;2) at (1.5,1.5) {\Large \ensuremath{1}};
#       \node[anchor=center] (8;3) at (2.5,1.5) {\Large \ensuremath{2}};
#       \node[anchor=center] (8;4) at (3.5,1.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (8;5) at (4.5,1.5) {\Large \ensuremath{1}};
#       \node[anchor=center] (8;6) at (5.5,1.5) {\Large \ensuremath{2}};
#       \node[anchor=center] (8;7) at (6.5,1.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (8;8) at (7.5,1.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (8;9) at (8.5,1.5) {\Large \ensuremath{2}};
#       \node[anchor=center] (9;1) at (0.5,0.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (9;2) at (1.5,0.5) {\Large \ensuremath{2}};
#       \node[anchor=center] (9;3) at (2.5,0.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (9;4) at (3.5,0.5) {\Large \ensuremath{1}};
#       \node[anchor=center] (9;5) at (4.5,0.5) {\Large \ensuremath{0}};
#       \node[anchor=center] (9;6) at (5.5,0.5) {\Large \ensuremath{1}};
#       \node[anchor=center] (9;7) at (6.5,0.5) {\Large \ensuremath{2}};
#       \node[anchor=center] (9;8) at (7.5,0.5) {\Large \ensuremath{2}};
#       \node[anchor=center] (9;9) at (8.5,0.5) {\Large \ensuremath{1}};
#   \end{scope}
# \end{tikzpicture}
